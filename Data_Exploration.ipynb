# %% [markdown]
# ## Task 1: Data Preparation

# %% [markdown]
# ## Data Retrieving
# ## Point 1: Loading the CSV data

# %%
import pandas as pd

# %%
pd.options.mode.chained_assignment = None  # default='warn'

# %%
automobile_filename = "automobile.csv"

# %%
automobile=pd.read_csv(automobile_filename, sep='#', decimal='.', header = None, \
                      names=['Symboling', 'Normalised-losses', 'Make', 'Fuel-type', 'Aspiration', 'Num-of-doors', 'Body-style',
                             'Drive-wheels', 'Engine-location', 'Wheel-base', 'Length','Width', 'Height', 'Curb-weight', 'Engine-type',
                             'Num-of-cylinders', 'Engine-size', 'Fuel-system', 'Bore', 'Stroke', 'Compression-ratio', 'Horsepower',
                             'Peak-rpm', 'City-mpg', 'Highway-mpg', 'Price'])
automobile
# Out:
#      Symboling  Normalised-losses         Make Fuel-type Aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            3                NaN  alfa-romero       gas        std
# 2            1                NaN  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 233         -1               95.0       volvo        gas        std
# 234         -1                NaN       volvo     diesel      turbo
# 235         -1                NaN   vol00112ov       gas      turbo
# 236         -1               95.0        volvo    diesel   turrrrbo
# 237         -1               95.0        volvo       gas      turbo
#
#     Num-of-doors   Body-style Drive-wheels Engine-location  Wheel-base  ...  \
# ...

# %% [markdown]
# ## To get last few rows from the columns

# %%
automobile.tail(6)
# Out:
#      Symboling  Normalised-losses        Make Fuel-type Aspiration  \
# 232         -1               95.0      volvo        gas      turbo
# 233         -1               95.0      volvo        gas        std
# 234         -1                NaN      volvo     diesel      turbo
# 235         -1                NaN  vol00112ov       gas      turbo
# 236         -1               95.0       volvo    diesel   turrrrbo
# 237         -1               95.0       volvo       gas      turbo
#
#     Num-of-doors Body-style Drive-wheels Engine-location  Wheel-base  ...  \
# 232         four      sedan          rwd           front       109.1  ...
# 233         four      sedan          rwd           front       109.1  ...
# 234         four      sedan          rwd           front       109.1  ...
# 235         four      sedan          rwd           front       109.1  ...
# 236         four      sedan          rwd           front       109.1  ...
# ...

# %% [markdown]
# ## To get the first few initial rows from the columns

# %%
print(automobile.head())
# Out:
#    Symboling  Normalised-losses         Make Fuel-type Aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   Num-of-doors   Body-style Drive-wheels Engine-location  Wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    Engine-size  Fuel-system  Bore  Stroke Compression-ratio Horsepower  \
# ...

# %% [markdown]
# ## Point 2: Checking the types of loaded columns
# Here, `automobile.dtypes` function is used to check the datatypes of the 'automobile' dataset's loaded columns. As an output, few variables are found which are integers and whole numbers that named as 'Symboling','Curb-weight','Engine-size','City-mpg','Highway-mpg'. On the other hand, some floating numbers also have obtained which are known as 'Normalised-losses','Wheel-base','Length','Width','Height','Bore','Stroke','Compression-ratio','Horse-power','Peak-rpm','Price'. Apart from these, other variables are highlighting as 'object' datatypes.

# %%
automobile.dtypes
# Out:
# Symboling              int64
# Normalised-losses    float64
# Make                  object
# Fuel-type             object
# Aspiration            object
# Num-of-doors          object
# Body-style            object
# Drive-wheels          object
# Engine-location       object
# Wheel-base           float64
# Length               float64
# Width                float64
# Height               float64
# Curb-weight            int64
# Engine-type           object
# Num-of-cylinders      object
# Engine-size            int64
# Fuel-system           object
# Bore                 float64
# Stroke               float64
# Compression-ratio    float64
# Horsepower           float64
# Peak-rpm             float64
# City-mpg               int64
# Highway-mpg            int64
# Price                float64
# dtype: object

# %% [markdown]
# The entire `automobile` dataframe's structure has been checked using info() function where 238 observations(rows) and 26 variables(columns) have been found as an output. Apart from this, 11 floating64, 5 int64 and 10 object data types have been found from this automobile dataset which are enlightened in the below output pane.

# %%
automobile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Symboling          238 non-null    int64
#  1   Normalised-losses  191 non-null    float64
#  2   Make               238 non-null    object
#  3   Fuel-type          238 non-null    object
#  4   Aspiration         238 non-null    object
#  5   Num-of-doors       236 non-null    object
#  6   Body-style         238 non-null    object
#  7   Drive-wheels       238 non-null    object
#  8   Engine-location    238 non-null    object
#  9   Wheel-base         238 non-null    float64
#  10  Length             238 non-null    float64
#  11  Width              238 non-null    float64
#  12  Height             238 non-null    float64
#  13  Curb-weight        238 non-null    int64
#  14  Engine-type        238 non-null    object
#  15  Num-of-cylinders   238 non-null    object
# ...

# %% [markdown]
# In the following step, conversion process has been done where `Make`, `Body-style` and `Engine-type`variables are converted from `object` datatypes to `category` types using `astype()` function.

# %%
automobile['Make'] = automobile['Make'].astype('category')
automobile['Body-style'] = automobile['Body-style'].astype('category')
automobile['Engine-type'] = automobile['Engine-type'].astype('category')

# %% [markdown]
# Here, all variables' data types and structures have been checked again using info() function and found that `Make`, `Body-style`, and `Engine-type` have been converted as `category` data type from `object` data type using `astype()` function.

# %%
automobile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Symboling          238 non-null    int64
#  1   Normalised-losses  191 non-null    float64
#  2   Make               238 non-null    category
#  3   Fuel-type          238 non-null    object
#  4   Aspiration         238 non-null    object
#  5   Num-of-doors       236 non-null    object
#  6   Body-style         238 non-null    category
#  7   Drive-wheels       238 non-null    object
#  8   Engine-location    238 non-null    object
#  9   Wheel-base         238 non-null    float64
#  10  Length             238 non-null    float64
#  11  Width              238 non-null    float64
#  12  Height             238 non-null    float64
#  13  Curb-weight        238 non-null    int64
#  14  Engine-type        238 non-null    category
#  15  Num-of-cylinders   238 non-null    object
# ...

# %% [markdown]
# In the following step, `Num-of-doors` column is extracted using `automobile[column's name]` function to get explicit information about it's values where all values length is showing 238 and data type is object in the output part.

# %%
automobile['Num-of-doors']
# Out:
# 0        two
# 1        two
# 2        two
# 3       four
# 4       four
#        ...
# 233     four
# 234     four
# 235     four
# 236     four
# 237    fourR
# Name: Num-of-doors, Length: 238, dtype: object

# %% [markdown]
# Here,`value.counts()` function has been used and different kinds of values have obtained from the output pane which are having different characteristics such as upper-case, extra-whitespace etc.

# %%
automobile['Num-of-doors'].value_counts()
# Out:
# four     142
# two       89
# fourR      3
# four       1
# Four       1
# Name: Num-of-doors, dtype: int64

# %%
labels = automobile['Num-of-doors'].unique()
labels
# In this step, the values of `Num-of-doors` have been checked again clearly using `unique()` function where missing 
# value and other characteristics values are entitled as an output.
# Out:
# array(['two', 'four', nan, 'Four', 'four ', 'fourR'], dtype=object)

# %%
automobile['Num-of-doors'].replace('Four', 'four', inplace=True)
# Here, `replace()` function has been used using `inplace=True` argument which helps to change into wrong format to right format.
# For instance, `Four` was showing inconsistency with the other values in the `Num-of-doors` variable. That is why, it has been 
# replaced with the `four` value using `replace()`.

# %%
automobile['Num-of-doors'].value_counts()
# The `value_counts()` has been used again to check the change of the above value `Four` to `four` and 143 `four` values have been 
# obtained where 142 `four` values were in  the previous step.
# Out:
# four     143
# two       89
# fourR      3
# four       1
# Name: Num-of-doors, dtype: int64

# %% [markdown]
# Here, The `replace()` function has been used again applying `inplace=True` argument to replace the incorrect `fourR` value with the correct spelling `four` value.

# %%
automobile['Num-of-doors'].replace('fourR', 'four', inplace=True)

# %% [markdown]
# In this step, the `value_counts()` function is used again to check the number of `four` values and 146 `four`
# values are obtained as an output.

# %%
automobile['Num-of-doors'].value_counts()
# Out:
# four     146
# two       89
# four       1
# Name: Num-of-doors, dtype: int64

# %%
automobile['Num-of-doors'] = automobile['Num-of-doors'].str.strip()
# This step has been used for reducing white-space by applying `str.strip()` function.

# %% [markdown]
# After using `str.strip()` function, 147 observations for `four` values and 89 observations for `two` values have been found as an output which has checked using `value_counts()` function.

# %%
automobile['Num-of-doors'].value_counts()
# Out:
# four    147
# two      89
# Name: Num-of-doors, dtype: int64

# %% [markdown]
# To check the values of `Num-of-doors` uniquely and apparently, `unique()` function has been applied again where `two`,`four`, `nan` values are obtained as an output.

# %%
labels = automobile['Num-of-doors'].unique()
labels
# Out:
# array(['two', 'four', nan], dtype=object)

# %%
automobile = automobile[automobile['Num-of-doors'].notna()] 
# As the missing values have found from the output of the `unique()` function, `notna()` function has been applied to delete the missing values.

# %%
labels = automobile['Num-of-doors'].unique()
labels
# To check the missing values finally, `unique()` function is used for the `Num-of-doors` variable and found that only `two` 
# and `four` values are enlightened as an output.
# Out:
# array(['two', 'four'], dtype=object)

# %% [markdown]
# Here, `astype()` function has been used to convert few more data types from `object` to `category` which are known as 'Num-of-doors', 'Fuel-type', 'Drive-wheels'.

# %%
automobile['Num-of-doors'] = automobile['Num-of-doors'].astype('category')

# %%
automobile['Fuel-type'] = automobile['Fuel-type'].astype('category')
automobile['Drive-wheels'] = automobile['Drive-wheels'].astype('category')

# %% [markdown]
# Here, `automobile.dtypes` function is used again to check the datatypes of the 'automobile' dataset's loaded columns. In the output, few more variables are found as `category` data types named as 'Fuel-type', 'Num-of-doors', 'Drive-wheels'.

# %%
automobile.dtypes
# Out:
# Symboling               int64
# Normalised-losses     float64
# Make                 category
# Fuel-type            category
# Aspiration             object
# Num-of-doors         category
# Body-style           category
# Drive-wheels         category
# Engine-location        object
# Wheel-base            float64
# Length                float64
# Width                 float64
# Height                float64
# Curb-weight             int64
# Engine-type          category
# Num-of-cylinders       object
# Engine-size             int64
# Fuel-system            object
# Bore                  float64
# Stroke                float64
# Compression-ratio     float64
# Horsepower            float64
# Peak-rpm              float64
# City-mpg                int64
# Highway-mpg             int64
# Price                 float64
# dtype: object

# %% [markdown]
# In the following step, `Num-of-cylinders` column is extracted to get explicit information about it's values where all values length is 236 and data type is object.

# %%
automobile['Num-of-cylinders']
# Out:
# 0      four
# 1      four
# 2       six
# 3      four
# 4      five
#        ...
# 233     six
# 234     six
# 235    four
# 236     six
# 237    four
# Name: Num-of-cylinders, Length: 236, dtype: object

# %% [markdown]
# To find the values of `Num-of-cylinders` uniquely, the `unique()` function has been applied where 'two', 'three', 'four', 'five', 'six', 'eight', 'twelve', 'five ', ' four' 'Four' values are obtained as an output.

# %%
labels = automobile['Num-of-cylinders'].unique()
labels
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight', 'Four',
#        'five ', ' four'], dtype=object)

# %% [markdown]
# Here, The `replace()` function has been applied for the `Num-of-cylinders` variable using `inplace=True` argument to replace the upper-case `F` alphabet from Four value with the lower-case `f` alphabet for correct spelling `four` value.

# %%
automobile['Num-of-cylinders'].replace('Four', 'four', inplace=True)

# %% [markdown]
# In this step, the `value_counts()` function is used again to check the number of `four` values of the `Num-of-cylinders` variable's and 175 `four` values are obtained as an output.

# %%
automobile['Num-of-cylinders'].value_counts()
# Out:
# four      175
# six        37
# five       10
# eight       5
# two         4
#  four       2
# five        1
# three       1
# twelve      1
# Name: Num-of-cylinders, dtype: int64

# %% [markdown]
# The `Num-of-cylinders` variable's unique values have checked using `unique()` function and obtained some different values as an output.

# %%
labels = automobile['Num-of-cylinders'].unique()
labels
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight', 'five ',
#        ' four'], dtype=object)

# %%
automobile['Num-of-cylinders'] = automobile['Num-of-cylinders'].str.strip()
# This step has been used for the 'Num-of-cylinders' variable's to reduce white-space applying `str.strip()` function.

# %% [markdown]
# The `value_counts()` function is used again to check the redundency such as white-space of the `Num-of-cylinders`
# variable's. After the manipulation and using `str.strip()` and `value_counts()` functions, 177 `four` values are obtained as an output in the subsequent step.

# %%
automobile['Num-of-cylinders'].value_counts()
# Out:
# four      177
# six        37
# five       11
# eight       5
# two         4
# three       1
# twelve      1
# Name: Num-of-cylinders, dtype: int64

# %% [markdown]
# ## Map 'Num-of-cylinders' to integer label [4,6,5,3,12,2,8]

# %% [markdown]
# In the following step, `dict()` function has been used to zip all the values together and to keep irreversible where 'in Python, a Dictionary can be created by placing a sequence of elements within curly {} braces, separated by ‘comma’ as well as Dictionary holds pairs of values, one being the Key and the other corresponding pair element being its Key:value. Apart from this, values in a dictionary can be of any data type and can be duplicated, whereas keys can’t be repeated and must be immutable'. Here, as an output 'four':4, 'six':6, 'five':5, 'three':3, 'twelve':12, 'two':2,'eight':8 are obtained for the object `label-to-integer`.

# %%
label_to_integer=dict(zip(labels,[4,6,5,3,12,2,8]))
label_to_integer
# Out:
# {'four': 4,
#  'six': 6,
#  'five': 5,
#  'three': 3,
#  'twelve': 12,
#  'two': 2,
#  'eight': 8}

# %% [markdown]
# Here, the replace() function has been applied for the `Num-of-cylinders` variable again using `inplace=True` argument to replace the string values into the numeric values.

# %%
automobile['Num-of-cylinders'].replace(label_to_integer, inplace=True)

# %% [markdown]
# After replacing operation, few values such as 4, 6, 5, 3, 12, 2, 8 have found using `unique()` function which are replaced as an integer and enlightened as an output in the following step.

# %%
labels = automobile['Num-of-cylinders'].unique()
labels
# Out:
# array([ 4,  6,  5,  3, 12,  2,  8], dtype=int64)

# %% [markdown]
# In the next cell, the `value_counts()` function is used again to check the redundency such as white-space of the `Num-of-cylinders` variable's. After the manipulation and using `str.strip()` and `value_counts()` functions, as an output 177,37,11,5,4,1,1 observations are obtained for `4`,`6`,`5`,`8`,`2`,`3`,`12` values respectively.

# %%
automobile['Num-of-cylinders'].value_counts()
# Out:
# 4     177
# 6      37
# 5      11
# 8       5
# 2       4
# 3       1
# 12      1
# Name: Num-of-cylinders, dtype: int64

# %% [markdown]
# Eventually, the entire automobile dataframe's structure has been checked again using `info()` function where 238 observations(rows) and 26 variables(columns) have been found as an output. Apart from this, 6 category, 11 floating64, 6 int64, and 3 object data types have been found from this automobile dataset which are enlightened in the below output pane. Additionally, the `Num-of-cylinders` variable's data type has changed from `object` to `integer` data type which is also highlighted in the output.

# %%
automobile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 236 entries, 0 to 237
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Symboling          236 non-null    int64
#  1   Normalised-losses  190 non-null    float64
#  2   Make               236 non-null    category
#  3   Fuel-type          236 non-null    category
#  4   Aspiration         236 non-null    object
#  5   Num-of-doors       236 non-null    category
#  6   Body-style         236 non-null    category
#  7   Drive-wheels       236 non-null    category
#  8   Engine-location    236 non-null    object
#  9   Wheel-base         236 non-null    float64
#  10  Length             236 non-null    float64
#  11  Width              236 non-null    float64
#  12  Height             236 non-null    float64
#  13  Curb-weight        236 non-null    int64
#  14  Engine-type        236 non-null    category
# ...

# %% [markdown]
# ## Typos

# %% [markdown]
# ## Point 3: Checking whether there are typos in the data and using mask to correct the typos

# %% [markdown]
# Here, the mask has been created with the `mask_automobile` object. As the mask is Boolean values and makes a condition, some data have been selected using mask which are smaller than (-3) in the `Symboling` variable. But, unfortunately, there are no values which are smaller than (-3) named as -4, -5 and so on in the `Symboling` variable resulting 0 rows and 26 columns have obtained as an output using the `head()` function which are highlighting in the following step.

# %%
mask_automobile=(automobile['Symboling'] < -3)

# %%
automobile[mask_automobile].head(60)
# Out:
# Empty DataFrame
# Columns: [Symboling, Normalised-losses, Make, Fuel-type, Aspiration, Num-of-doors, Body-style, Drive-wheels, Engine-location, Wheel-base, Length, Width, Height, Curb-weight, Engine-type, Num-of-cylinders, Engine-size, Fuel-system, Bore, Stroke, Compression-ratio, Horsepower, Peak-rpm, City-mpg, Highway-mpg, Price]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# In the below step, the mask has been generated again with the `mask_automobile` object. By applying this mask, some data have been selected which are greater than 3 in the `Symboling` variable. But, unfortunately,only three values have been found which are greater than 3 and named as impossible value '4'. Because, according to the automobile condition, +3 indicates high-risk auto whether -3 indicates safe. As a result, +4 is a impossible value for auto condition which is very high-risk and uncountable for it's safety. Additionally, it is also known as a typing error which needs to be fixed. Apart from this, 3 rows and 26 columns have obtained as an output using the `head()` function.

# %%
mask_automobile=(automobile['Symboling'] > 3)
automobile[mask_automobile].head(60)
# Out:
#      Symboling  Normalised-losses    Make Fuel-type Aspiration Num-of-doors  \
# 205          4               25.0  volvo        gas        std         four
# 218          4               25.0  volvo        gas        std         four
# 231          4               25.0  volvo        gas        std         four
#
#     Body-style Drive-wheels Engine-location  Wheel-base  ...  Engine-size  \
# 205      sedan          rwd           front       109.1  ...          141
# 218      sedan          rwd           front       109.1  ...          141
# 231      sedan          rwd           front       109.1  ...          141
#
#      Fuel-system  Bore  Stroke Compression-ratio  Horsepower  Peak-rpm  \
# 205         mpfi  3.78    3.15               9.5       114.0    5400.0
# 218         mpfi  3.78    3.15               9.5       114.0    5400.0
# 231         mpfi  3.78    3.15               9.5       114.0    5400.0
#
#     City-mpg  Highway-mpg    Price
# 205       23           28  16845.0
# ...

# %% [markdown]
# As this `+4` value is uncountable and impossible for auto's safety, hence, it should drop from the rows of the `automobile` data set. To drop this impossible value, specific range is used to form the mask and localize every rows where `Symboling` variable's values are less than `4`.

# %%
automobile = automobile.loc[automobile['Symboling'] < 4]

# %% [markdown]
# To check the dropping result of impossible value '4', `value_counts()` function has been used and found that no impossible
# values are staying in the output pane.

# %%
automobile['Symboling'].value_counts()
# Out:
#  0    66
#  1    53
# -1    52
#  2    32
#  3    27
# -2     3
# Name: Symboling, dtype: int64

# %% [markdown]
# To double check for the impossible values, `unique()` function is applied where resulting only showing six values except
# impossible value '4'.

# %%
labels = automobile['Symboling'].unique()
labels
# Out:
# array([ 3,  1,  2,  0, -1, -2], dtype=int64)

# %% [markdown]
# To check the `Make` variable's typing error,  `unique()` function has been applied where 'vol00112ov' values are found as the
# typing error corresponding with the `volvo` brand name.

# %%
labels = automobile['Make'].unique()
labels
# Out:
# ['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', ..., 'volkswagen', 'volvo', ' volvo ', 'volvo ', 'vol00112ov']
# Length: 27
# Categories (27, object): ['alfa-romero', 'audi', 'bmw', 'chevrolet', ..., 'volvo', ' volvo ', 'volvo ', 'vol00112ov']

# %%
automobile['Make'].replace( 'vol00112ov', 'volvo', inplace=True)
# Then in this step, `replace()` function is used with the `inplace=True` argument to change the incorrect name 'vol00112ov'
# into the correct name 'volvo'.

# %% [markdown]
# To check the replacing result of incorrect name 'vol00112ov', value_counts() function is applied and obtained that incorrect
# name has been changed into correct name 'volvo' which are highlighting in th output pane and added with the correct name by extending the number of values.

# %%
automobile['Make'].value_counts()
# Out:
# volvo            32
# toyota           32
# nissan           17
# mazda            16
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           10
# bmw               8
# dodge             8
# mercedes-benz     8
# plymouth          7
# audi              7
# volvo             6
# saab              6
# porsche           5
# isuzu             4
#  volvo            3
# jaguar            3
# chevrolet         3
# alfa-romero       3
# renault           2
# Nissan            1
# Peugot            1
# mercury           1
# Name: Make, dtype: int64

# %%
labels = automobile['Make'].unique()
labels
# To double check for the incorrect name `vol00112ov`, unique() function is applied where found that incorrect name 'vol00112ov'
# has been changed into 'volvo' name.
# Out:
# ['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', ..., 'toyota', 'volkswagen', 'volvo', ' volvo ', 'volvo ']
# Length: 26
# Categories (26, object): ['alfa-romero', 'audi', 'bmw', 'chevrolet', ..., 'volkswagen', 'volvo', ' volvo ', 'volvo ']

# %%
labels = automobile['Fuel-type'].unique()
labels
# To check the 'Fuel-type' variable's typing error, unique() function has been used where found only few upper-case and lower-case 
# inconsistency.
# Out:
# ['gas', 'diesel', 'Gas', 'Diesel', 'gas ']
# Categories (5, object): ['gas', 'diesel', 'Gas', 'Diesel', 'gas ']

# %%
labels = automobile['Body-style'].unique()
labels
# To check the 'Body-style' variable's typing error, unique() function has been used where found only few upper-case and lower-case 
# incompatibility.
# Out:
# ['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop', 'Sedan', 'Wagon', 'sedan ']
# Categories (8, object): ['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop', 'Sedan', 'Wagon', 'sedan ']

# %%
labels = automobile['Drive-wheels'].unique()
labels
# To find the 'Drive-wheels' variable's typing error, unique() function has been applied where '4wd' values are found 
# as the typing error corresponding with the 'fwd' name.
# Out:
# ['rwd', 'fwd', '4wd', 'Fwd', 'fwd ', 'rwd ']
# Categories (6, object): ['rwd', 'fwd', '4wd', 'Fwd', 'fwd ', 'rwd ']

# %%
automobile['Drive-wheels'].value_counts()
# To find the 'Drive-wheels' variable's typing error, 'value_counts()' function has been used where '4wd' values are found 
# as the typing error which numbers are 9.
# Out:
# fwd     116
# rwd     105
# 4wd       9
# Fwd       1
# fwd       1
# rwd       1
# Name: Drive-wheels, dtype: int64

# %%
automobile['Drive-wheels'].replace( '4wd', 'fwd', inplace=True)
# Then in this step, `replace()` function is used with the `inplace=True` argument to change the incorrect name '4wd'
# into the correct name 'fwd'.

# %% [markdown]
# To check the replacing result of incorrect name '4wd', value_counts() function is used and found that incorrect name has been changed into correct name 'fwd' which are highlighting in th output pane and added with the correct name by extending the number of values from 116 to 125.

# %%
automobile['Drive-wheels'].value_counts()
# Out:
# fwd     125
# rwd     105
# Fwd       1
# fwd       1
# rwd       1
# Name: Drive-wheels, dtype: int64

# %%
labels = automobile['Engine-type'].unique()
labels
# To find the 'Engine-type' variable's typing error, unique() function has been applied where 'l' values are found 
# as the typing error corresponding with the 'ohc' engine-type name.
# Out:
# ['dohc', 'ohcv', 'ohc', 'l', 'rotor', 'Ohc', 'ohcf', 'dohcv']
# Categories (8, object): ['dohc', 'ohcv', 'ohc', 'l', 'rotor', 'Ohc', 'ohcf', 'dohcv']

# %% [markdown]
# To check the `Engine-type` variable's typing error, `value_counts()` function has been used where `l` values are found
# as the typing error which numbers are 12.

# %%
automobile['Engine-type'].value_counts()
# Out:
# ohc      170
# ohcv      18
# ohcf      15
# dohc      12
# l         12
# rotor      4
# Ohc        1
# dohcv      1
# Name: Engine-type, dtype: int64

# %%
automobile['Engine-type'].replace('l', 'dohc', inplace=True)
# Then in this step, `replace()` function is used with the `inplace=True` argument to change the incorrect name 'l'
# into the correct name 'dohc'.

# %% [markdown]
# To check the replacing result of incorrect name `l`, value_counts() function is used and found that incorrect name has been changed into correct name `dohc` which are enlighting in th output pane and added with the correct name by extending the number of values from 12 to 24.

# %%
automobile['Engine-type'].value_counts()
# Out:
# ohc      170
# dohc      24
# ohcv      18
# ohcf      15
# rotor      4
# Ohc        1
# dohcv      1
# Name: Engine-type, dtype: int64

# %% [markdown]
# To find the `Aspiration` variable's typing error, value_counts() function has been used where `turrrrbo` values are found as the typing error which numbers are 3.

# %%
automobile['Aspiration'].value_counts()
# Out:
# std         171
# turbo        56
# turrrrbo      3
# Std           2
# std           1
# Name: Aspiration, dtype: int64

# %%
automobile['Aspiration'].replace('turrrrbo', 'turbo', inplace=True)
# Then in this step, `replace()` function is used with the `inplace=True` argument to change the incorrect name 'turrrrbo'
# into the correct name 'turbo'.

# %%
labels = automobile['Aspiration'].unique()
labels
# To find the 'Aspiration' variable's typing error uniquely, 'unique()' function has been applied where 'turrrrbo' values are 
# found as the typing error corresponding with the correct name 'turbo'.
# Out:
# array(['std', 'turbo', 'Std', 'std '], dtype=object)

# %% [markdown]
# To check the replacing result of incorrect name `turrrrbo`, value_counts() function is applied and obtained that incorrect name has been changed into correct name `turbo` which are showing in the output pane and added with the correct name by extending the number of values from 56 to 59.

# %%
automobile['Aspiration'].value_counts()
# Out:
# std      171
# turbo     59
# Std        2
# std        1
# Name: Aspiration, dtype: int64

# %% [markdown]
# ## Point 4: Extra-whitespaces

# %% [markdown]
# To find the `Make` variable's extra-whitespace error, value_counts() function is used where 'volvo' value is highlighting it's extra-whitespace error.

# %%
automobile['Make'].value_counts()
# Out:
# volvo            32
# toyota           32
# nissan           17
# mazda            16
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           10
# bmw               8
# dodge             8
# mercedes-benz     8
# plymouth          7
# audi              7
# volvo             6
# saab              6
# porsche           5
# isuzu             4
#  volvo            3
# jaguar            3
# chevrolet         3
# alfa-romero       3
# renault           2
# Nissan            1
# Peugot            1
# mercury           1
# Name: Make, dtype: int64

# %% [markdown]
# To check the `Make` variable's extra-whitespace error uniquely, `unique()` function has been applied where ' volvo ', 'volvo '  values are found as the extra-whitespace error comparing with the correct name 'volvo'.

# %%
labels = automobile['Make'].unique()
labels
# Out:
# ['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', ..., 'toyota', 'volkswagen', 'volvo', ' volvo ', 'volvo ']
# Length: 26
# Categories (26, object): ['alfa-romero', 'audi', 'bmw', 'chevrolet', ..., 'volkswagen', 'volvo', ' volvo ', 'volvo ']

# %%
automobile['Make']= automobile['Make'].str.strip()
# Then in this step, `str.strip()` function is used for the `Make` variable to fix the extra-whitespace error of 'volvo' value.

# %% [markdown]
# To check the fixing result, value_counts() function is applied and obtained the correct name `volvo` which are showing in the output pane and added with the correct name 'volvo' by extending the number of values from 32 to 41.

# %%
automobile['Make'].value_counts()
# Out:
# volvo            41
# toyota           32
# nissan           17
# mazda            16
# honda            13
# mitsubishi       13
# subaru           12
# volkswagen       12
# peugot           10
# bmw               8
# dodge             8
# mercedes-benz     8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# chevrolet         3
# jaguar            3
# alfa-romero       3
# renault           2
# Nissan            1
# mercury           1
# Peugot            1
# Name: Make, dtype: int64

# %% [markdown]
# The `Make` variable's extra-whitespace error has been checked uniquely using `unique()` function where ' volvo ', 'volvo ' values' extra-whitespaces are fixed with the correct name 'volvo' which are shown in the output pane.

# %%
labels = automobile['Make'].unique()
labels
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'Nissan', 'Peugot', 'peugot', 'plymouth',
#        'porsche', 'renault', 'saab', 'subaru', 'toyota', 'volkswagen',
#        'volvo'], dtype=object)

# %% [markdown]
# To find the `Fuel-type` variable's extra-whitespace error, value_counts() function is used where 'gas' value is highlighting it's extra-whitespace error as 'gas '.

# %%
automobile['Fuel-type'].value_counts()
# Out:
# gas       203
# diesel     26
# Gas         2
# Diesel      1
# gas         1
# Name: Fuel-type, dtype: int64

# %% [markdown]
# To check the `Fuel-type` variable's extra-whitespace error uniquely, `unique()` function has been applied where 'gas ' values are found as the extra-whitespace error comparing with the correct name 'gas'.

# %%
labels = automobile['Fuel-type'].unique()
labels
# Out:
# ['gas', 'diesel', 'Gas', 'Diesel', 'gas ']
# Categories (5, object): ['gas', 'diesel', 'Gas', 'Diesel', 'gas ']

# %%
automobile['Fuel-type']= automobile['Fuel-type'].str.strip()
# Then in this step, `str.strip()` function is used for the `Fuel-type` variable to fix the extra-whitespace error of 'gas' value.

# %% [markdown]
# The `Fuel-type` variable's extra-whitespace error has been checked uniquely using`unique()` function where 'gas ' values' extra-whitespaces are fixed with the correct name 'gas' which are shown in the output pane.

# %%
labels = automobile['Fuel-type'].unique()
labels
# Out:
# array(['gas', 'diesel', 'Gas', 'Diesel'], dtype=object)

# %% [markdown]
# To check the `Body-style` variable's extra-whitespace error, `value_counts()` function has used where 'sedan' value is highlighting it's extra-whitespace error as 'sedan '.

# %%
automobile['Body-style'].value_counts()
# Out:
# sedan          119
# hatchback       70
# wagon           26
# hardtop          8
# convertible      6
# sedan            2
# Sedan            1
# Wagon            1
# Name: Body-style, dtype: int64

# %% [markdown]
# To find the `Body-style` variable's extra-whitespace error uniquely, unique() function has been applied where 'sedan ' values are found as the extra-whitespace error comparing with the correct name 'sedan'.

# %%
labels = automobile['Body-style'].unique()
labels
# Out:
# ['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop', 'Sedan', 'Wagon', 'sedan ']
# Categories (8, object): ['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop', 'Sedan', 'Wagon', 'sedan ']

# %%
automobile['Body-style']= automobile['Body-style'].str.strip()
# Then in this step, `str.strip()` function is used for the `Body-style` variable to fix the extra-whitespace error of 'sedan' value.

# %% [markdown]
# To check the fixing result of `Body-style` variable's, `value_counts()` function is applied and obtained the correct name `sedan` which are showing in the output pane and added with the correct name `sedan` by extending the number of values from 119 to 121.

# %%
automobile['Body-style'].value_counts()
# Out:
# sedan          121
# hatchback       70
# wagon           26
# hardtop          8
# convertible      6
# Sedan            1
# Wagon            1
# Name: Body-style, dtype: int64

# %% [markdown]
# Finally, the `Body-style` variable's extra-whitespace error has been checked uniquely using `unique()` function where 'sedan ' values' extra-whitespaces are fixed with the correct name 'sedan' which are shown in the output pane.

# %%
labels = automobile['Body-style'].unique()
labels
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop', 'Sedan',
#        'Wagon'], dtype=object)

# %% [markdown]
# To find the `Engine-type` variable's extra-whitespace error uniquely, `unique()` function has been applied where no values are found as the extra-whitespace error comparing with the other correct values' spaces such as 'dohc', 'ohcv', 'ohc', 'rotor', 'Ohc', 'ohcf', 'dohcv'.

# %%
labels = automobile['Engine-type'].unique()
labels
# Out:
# ['dohc', 'ohcv', 'ohc', 'rotor', 'Ohc', 'ohcf', 'dohcv']
# Categories (7, object): ['dohc', 'ohcv', 'ohc', 'rotor', 'Ohc', 'ohcf', 'dohcv']

# %%
automobile['Engine-type']= automobile['Engine-type'].str.strip()
# Then in this step, `str.strip()` function is applied for the `Engine-type` variable to fix the extra-whitespace error if there
# are any in here.

# %%
labels = automobile['Engine-type'].unique()
labels
# Out:
# array(['dohc', 'ohcv', 'ohc', 'rotor', 'Ohc', 'ohcf', 'dohcv'],
#       dtype=object)

# %% [markdown]
# To find the `Drive-wheels` variable's extra-whitespace error uniquely, `unique()` function has been applied where 'fwd ', 'rwd ' values are found as the extra-whitespace error comparing with the correct name 'fwd', 'rwd'.

# %%
labels = automobile['Drive-wheels'].unique()
labels
# Out:
# ['rwd', 'fwd', 'Fwd', 'fwd ', 'rwd ']
# Categories (5, object): ['rwd', 'fwd', 'Fwd', 'fwd ', 'rwd ']

# %%
automobile['Drive-wheels'].value_counts()
# Here, the `Drive-wheels` variable's number of values are checked using the `value_counts()` function.
# Out:
# fwd     125
# rwd     105
# Fwd       1
# fwd       1
# rwd       1
# Name: Drive-wheels, dtype: int64

# %%
automobile['Drive-wheels']= automobile['Drive-wheels'].str.strip()
# Then in this step, `str.strip()` function is applied for the `Drive-wheels` variable to fix the extra-whitespace error of 'fwd' and 'rwd' values.

# %% [markdown]
# To check the fixing result of `Drive-wheels` variable's, `value_counts()` function is used and obtained the correct name space as 'fwd' and 'rwd' which are showing in the output pane and added with the correct name 'fwd' and 'rwd' respectively by extending the number of values from 125 and 105 to 126 and 106 respectively.

# %%
automobile['Drive-wheels'].value_counts()
# Out:
# fwd    126
# rwd    106
# Fwd      1
# Name: Drive-wheels, dtype: int64

# %% [markdown]
# The `Drive-wheels` variable's extra-whitespace errors are checked uniquely using the `unique()` function where 'fwd ', 'rwd ' values' extra-whitespaces are fixed with the correct name space 'fwd' and 'rwd' which are shown in the output pane.

# %%
labels = automobile['Drive-wheels'].unique()
labels
# Out:
# array(['rwd', 'fwd', 'Fwd'], dtype=object)

# %% [markdown]
# The `Num-of-doors` variable's extra-whitespace errors are checked uniquely using the `unique()` function where no values are found as the extra-whitespace error comparing with the other correct values' spaces such as 'two', 'four'.

# %%
labels = automobile['Num-of-doors'].unique()
labels
# Out:
# ['two', 'four']
# Categories (2, object): ['two', 'four']

# %% [markdown]
# To find the `Aspiration` variable's extra-whitespace error uniquely, the `unique()` function has been applied where 'std ' value is found as the extra-whitespace error comparing with the correct name 'std'.

# %%
labels = automobile['Aspiration'].unique()
labels
# Out:
# array(['std', 'turbo', 'Std', 'std '], dtype=object)

# %%
automobile['Aspiration']= automobile['Aspiration'].str.strip()
# Then in this step, `str.strip()` function is applied for the `Aspiration` variable to fix the extra-whitespace error of 'std' value.

# %% [markdown]
# To find the `Aspiration` variable's extra-whitespace error uniquely, the `unique()` function has been applied where 'std ' value is found as the extra-whitespace error comparing with the correct name 'std'.

# %%
labels = automobile['Aspiration'].unique()
labels
# Out:
# array(['std', 'turbo', 'Std'], dtype=object)

# %% [markdown]
# ## Point 5: Upper/Lower-case

# %% [markdown]
# To remove the inconsistency of upper and lower case of any variable's values, the lower-case values are only kept in this `automobile` dataset. Hence, the `Make` variable's upper-case errors are checked uniquely using the `unique()` function where 'Nissan', 'Peugot' values' are need to be fixed with the correct name 'nissan' and 'peugot' respectively which are shown in the output pane.

# %%
labels = automobile['Make'].unique()
labels
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'Nissan', 'Peugot', 'peugot', 'plymouth',
#        'porsche', 'renault', 'saab', 'subaru', 'toyota', 'volkswagen',
#        'volvo'], dtype=object)

# %% [markdown]
# Here, The `replace()` function is applied again using the `inplace=True` argument for replacing the upper `P` with the lower `p` of the `peugot` value.

# %%
automobile['Make'].replace('Peugot', 'peugot', inplace=True)

# %% [markdown]
# In the following step, the `replace()` function has been applied for the `Num-of-cylinders` variable using `inplace=True` argument to replace the upper-case `N` alphabet from `Nissan` value with the lower-case `n` alphabet for correct spelling of the `nissan` value.

# %%
automobile['Make'].replace('Nissan', 'nissan', inplace=True)

# %%
automobile['Make'].value_counts()
# Finally, the `Make` variable's number of values are checked using the `Value_counts()` function.
# Out:
# volvo            41
# toyota           32
# nissan           18
# mazda            16
# honda            13
# mitsubishi       13
# subaru           12
# volkswagen       12
# peugot           11
# bmw               8
# dodge             8
# mercedes-benz     8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# renault           2
# mercury           1
# Name: Make, dtype: int64

# %% [markdown]
# The `Fuel-type` variable's upper-case errors are checked uniquely using the `unique()` function where 'Gas', 'Diesel' values' are need to be fixed with the correct name 'gas' and 'diesel' respectively which are shown in the output pane.

# %%
labels = automobile['Fuel-type'].unique()
labels
# Out:
# array(['gas', 'diesel', 'Gas', 'Diesel'], dtype=object)

# %%
automobile['Fuel-type'].value_counts()
# The `Fuel-type` variable's number of values are checked using the `Value_counts()` function.
# Out:
# gas       204
# diesel     26
# Gas         2
# Diesel      1
# Name: Fuel-type, dtype: int64

# %% [markdown]
# Here, the `replace()` function is used again applying `inplace=True` argument to replace the incorrect `Gas` value with the correct lower-case value `gas`.

# %%
automobile['Fuel-type'].replace('Gas', 'gas', inplace=True)

# %% [markdown]
# In this step, the `replace()` function is applied again using the `inplace=True` argument for replacing the upper-case `D` with the lower-case `d` of the `diesel` value.

# %%
automobile['Fuel-type'].replace('Diesel', 'diesel', inplace=True)

# %% [markdown]
# The `Fuel-type` variable's upper-case errors are checked uniquely using the `unique()` function where 'Gas', 'Diesel' values' have been fixed with the correct name 'gas' and 'diesel' respectively and which are shown in the output pane

# %%
labels = automobile['Fuel-type'].unique()
labels
# Out:
# array(['gas', 'diesel'], dtype=object)

# %% [markdown]
# To check the fixing result of `Fuel-type` variable's, the `value_counts()` function is applied and obtained the correct name with the lower-case `gas` and `diesel` which are shown in the below output pane and added with the correct name by extending the number of values from 204 and 26 to 206 and 27 respectively.

# %%
automobile['Fuel-type'].value_counts()
# Out:
# gas       206
# diesel     27
# Name: Fuel-type, dtype: int64

# %% [markdown]
# The `Body-style` variable's upper-case errors are checked uniquely using the `unique()` function where 'Sedan' value needs to be changed with the correct lower-case name 'sedan' which are shown in the output pane.

# %%
labels = automobile['Body-style'].unique()
labels
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop', 'Sedan',
#        'Wagon'], dtype=object)

# %% [markdown]
# Here, the `replace()` function has been used again applying the `inplace=True` argument to replace the incorrect `Sedan` value with the correct spelling `sedan` value.

# %%
automobile['Body-style'].replace('Sedan', 'sedan', inplace=True)

# %%
automobile['Body-style'].value_counts()
# To find the `Body-style` variable's values number , the `value_counts()` function is used.
# Out:
# sedan          122
# hatchback       70
# wagon           26
# hardtop          8
# convertible      6
# Wagon            1
# Name: Body-style, dtype: int64

# %% [markdown]
# The `Drive-wheels` variable's upper-case errors are checked uniquely using the `unique()` function where 'Fwd' value needs to be fixed with the correct name 'fwd'which is shown in the output pane.

# %%
labels = automobile['Drive-wheels'].unique()
labels
# Out:
# array(['rwd', 'fwd', 'Fwd'], dtype=object)

# %% [markdown]
# Here, the `replace()` function has been used again applying `inplace=True` argument to replace the incorrect `Fwd` value with the correct lower-case value `fwd`.

# %%
automobile['Drive-wheels'].replace('Fwd', 'fwd', inplace=True)

# %%
automobile['Drive-wheels'].value_counts()
# To find the `Drive-wheels` variable's values number , the `value_counts()` function is used where as an output 'fwd' and 'rwd'
# values numbers are 127 and 106 respectively.
# Out:
# fwd    127
# rwd    106
# Name: Drive-wheels, dtype: int64

# %% [markdown]
# To find the `Engine-type` variable's values number, the `value_counts()` function is used where 'Ohc' value is highlighting it's upper-case error.

# %%
automobile['Engine-type'].value_counts()
# Out:
# ohc      170
# dohc      24
# ohcv      18
# ohcf      15
# rotor      4
# Ohc        1
# dohcv      1
# Name: Engine-type, dtype: int64

# %% [markdown]
# The `Engine-type` variable's upper-case errors are checked uniquely using the `unique()` function where 'Ohc' value needs to be fixed with the correct name 'ohc'which is shown in the output pane.

# %%
labels = automobile['Engine-type'].unique()
labels
# Out:
# array(['dohc', 'ohcv', 'ohc', 'rotor', 'Ohc', 'ohcf', 'dohcv'],
#       dtype=object)

# %% [markdown]
# Here, the `replace()` function has been used again applying `inplace=True` argument to replace the incorrect `Ohc` value with the correct lower-case value `ohc`.

# %%
automobile['Engine-type'].replace('Ohc', 'ohc', inplace=True)

# %% [markdown]
# To check the fixing result of `Engine-type` variable's, the `value_counts()` function is applied and obtained the correct name with the lower-case `ohc` which is shown in the below output pane and added with the correct name by extending the number of values from 170 to 171.

# %%
automobile['Engine-type'].value_counts()
# Out:
# ohc      171
# dohc      24
# ohcv      18
# ohcf      15
# rotor      4
# dohcv      1
# Name: Engine-type, dtype: int64

# %%
labels = automobile['Aspiration'].unique()
labels
# Using the `unique()` function, the unique values has been checked from the `Aspiration` variable.
# Out:
# array(['std', 'turbo', 'Std'], dtype=object)

# %% [markdown]
# Here, the `replace()` function has been used again applying `inplace=True` argument to replace the incorrect `Std` value with the correct lower-case value `std`.

# %%
automobile['Aspiration'].replace('Std', 'std', inplace=True)

# %%
automobile['Aspiration'].value_counts()
# The number of values of the `Aspiration` variable's has been checked using the `value_counts()` function and 'std','turbo' 
# values' numbers are 152 and 44 have been found as an output.
# Out:
# std      174
# turbo     59
# Name: Aspiration, dtype: int64

# %% [markdown]
# Finally, the whole `automobile` dataframe variables' values converted into lower-case using the `apply(lambda x:x.astype(str).str.lower())` function to remove any ambiguity about the upper-case and lower-case consistency.

# %%
automobile.apply(lambda x: x.astype(str).str.lower())
# Out:
#     Symboling Normalised-losses         Make Fuel-type Aspiration  \
# 0           3               nan  alfa-romero       gas        std
# 1           3               nan  alfa-romero       gas        std
# 2           1               nan  alfa-romero       gas        std
# 3           2             164.0         audi       gas        std
# 4           2             164.0         audi       gas        std
# ..        ...               ...          ...       ...        ...
# 233        -1              95.0        volvo       gas        std
# 234        -1               nan        volvo    diesel      turbo
# 235        -1               nan        volvo       gas      turbo
# 236        -1              95.0        volvo    diesel      turbo
# 237        -1              95.0        volvo       gas      turbo
#
#     Num-of-doors   Body-style Drive-wheels Engine-location Wheel-base  ...  \
# 0            two  convertible          rwd           front       88.6  ...
# ...

# %% [markdown]
# ## Point 6: Sanity Checks

# %%
labels=automobile['Symboling'].unique()
labels
# To check the sanity level of the `automobile` dataset, 'Symboling' variable's label has been checked and found the labels from
# 3 to -2 in the output pane.
# Out:
# array([ 3,  1,  2,  0, -1, -2], dtype=int64)

# %% [markdown]
# As the auto condition, +3 indicates high-risk and -3 indicates safe. Hence, for the automobile's safety, the `Symboling`
# variable's value should be kept below the value of +3. Therefore,this specific range of the 'Symboling' variable's value has been chosen using the following function which is smaller than +3 that may make this 'automobile' data more validable and acceptable.

# %%
automobile = automobile[automobile.Symboling < 3]
automobile
# Out:
#      Symboling  Normalised-losses         Make Fuel-type Aspiration  \
# 2            1                NaN  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# 5            2                NaN         audi       gas        std
# 6            1              158.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 233         -1               95.0        volvo       gas        std
# 234         -1                NaN        volvo    diesel      turbo
# 235         -1                NaN        volvo       gas      turbo
# 236         -1               95.0        volvo    diesel      turbo
# 237         -1               95.0        volvo       gas      turbo
#
#     Num-of-doors Body-style Drive-wheels Engine-location  Wheel-base  ...  \
# 2            two  hatchback          rwd           front        94.5  ...
# ...

# %% [markdown]
# In the subsequent step, the `value_counts()` function is used to check the the number of the `Symboling` variable's and to check the sanity of the `automobile` dataset where output is highlighting the values from 0 to -2 which are out of risk for any auto.

# %%
automobile['Symboling'].value_counts()
# Out:
#  0    66
#  1    53
# -1    52
#  2    32
# -2     3
# Name: Symboling, dtype: int64

# %%
automobile = automobile[automobile.Price > 0] 
automobile
# Here,it has been found that '0' is redundant value compare with the other values in the 'Price' variable which can also make 
# inconsistency in this'automobile' dataset. Hence, to extend the sanity of the dataset, 'Price' variable's values have been 
# modified using the above function.
# Out:
#      Symboling  Normalised-losses         Make Fuel-type Aspiration  \
# 2            1                NaN  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# 5            2                NaN         audi       gas        std
# 6            1              158.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 230         -1               95.0        volvo       gas      turbo
# 232         -1               95.0        volvo       gas      turbo
# 233         -1               95.0        volvo       gas        std
# 234         -1                NaN        volvo    diesel      turbo
# 235         -1                NaN        volvo       gas      turbo
#
#     Num-of-doors Body-style Drive-wheels Engine-location  Wheel-base  ...  \
# 2            two  hatchback          rwd           front        94.5  ...
# ...

# %% [markdown]
# To check the `Price` variable's values' numbers, the `value_counts()` function is used and found that there is no 'o' value highlighting in the output.

# %%
automobile['Price'].value_counts()
# Out:
# 21485.0    6
# 22470.0    6
# 22625.0    6
# 19045.0    6
# 16845.0    3
#           ..
# 12170.0    1
# 15580.0    1
# 20970.0    1
# 15750.0    1
# 11694.0    1
# Name: Price, Length: 159, dtype: int64

# %% [markdown]
# ## Point 7: Missing values

# %%
automobile.head()
# To check the missing values, `head()` function is used in this step. As a result, few missing values have found which known 
# as `NaN`(an acronym for Not a Number) and highlighting in the output pane.
# Out:
#    Symboling  Normalised-losses         Make Fuel-type Aspiration  \
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
# 5          2                NaN         audi       gas        std
# 6          1              158.0         audi       gas        std
#
#   Num-of-doors Body-style Drive-wheels Engine-location  Wheel-base  ...  \
# 2          two  hatchback          rwd           front        94.5  ...
# 3         four      sedan          fwd           front        99.8  ...
# 4         four      sedan          fwd           front        99.4  ...
# 5          two      sedan          fwd           front        99.8  ...
# 6         four      sedan          fwd           front       105.8  ...
#
#    Engine-size  Fuel-system  Bore  Stroke Compression-ratio  Horsepower  \
# ...

# %%
automobile.isnull()
# To check the missing values, the `isnull()` function has been used here and found that some `True` with all `False` values in 
# the variables which are the evidence of missing values that are highlighting in the output panel.
# Out:
#      Symboling  Normalised-losses   Make  Fuel-type  Aspiration  Num-of-doors  \
# 2        False               True  False      False       False         False
# 3        False              False  False      False       False         False
# 4        False              False  False      False       False         False
# 5        False               True  False      False       False         False
# 6        False              False  False      False       False         False
# ..         ...                ...    ...        ...         ...           ...
# 230      False              False  False      False       False         False
# 232      False              False  False      False       False         False
# 233      False              False  False      False       False         False
# 234      False               True  False      False       False         False
# 235      False               True  False      False       False         False
#
# ...

# %% [markdown]
# Here,'Pandas treat None and NaN as essentially interchangeable for indicating missing or null values'. Therefore, in order to drop the missing values, the `dropna()` function has been applied where'this function has dropped Rows/Columns of datasets with Null values in different ways'. Besides this, `automobile_new` object has been generated as a new clean and tidy automobile dataframe within the `dropna()` function which is enlightened all variables' values readable and acceptable in the output pane.

# %%
automobile_new= automobile.dropna()
automobile_new
# Out:
#      Symboling  Normalised-losses   Make Fuel-type Aspiration Num-of-doors  \
# 3            2              164.0   audi       gas        std         four
# 4            2              164.0   audi       gas        std         four
# 6            1              158.0   audi       gas        std         four
# 8            1              158.0   audi       gas      turbo         four
# 10           2              192.0    bmw       gas        std          two
# ..         ...                ...    ...       ...        ...          ...
# 228         -1               95.0  volvo       gas        std         four
# 229         -1               95.0  volvo    diesel      turbo         four
# 230         -1               95.0  volvo       gas      turbo         four
# 232         -1               95.0  volvo       gas      turbo         four
# 233         -1               95.0  volvo       gas        std         four
#
# ...

# %% [markdown]
# Here, all observations'(rows) and variables'(columns) missing values have checked using `.loc[]`, `isnull()`, and `sum()` functions together where `:`symbol is mentioning all rows and all columns of the `automobile_new` datset. After this manipulation, there are no missing values highlighted in the following output pane which have been proved by getting '0' for all variables.

# %%
automobile_new.loc[:,:].isnull().sum()
# Out:
# Symboling            0
# Normalised-losses    0
# Make                 0
# Fuel-type            0
# Aspiration           0
# Num-of-doors         0
# Body-style           0
# Drive-wheels         0
# Engine-location      0
# Wheel-base           0
# Length               0
# Width                0
# Height               0
# Curb-weight          0
# Engine-type          0
# Num-of-cylinders     0
# Engine-size          0
# Fuel-system          0
# Bore                 0
# Stroke               0
# Compression-ratio    0
# Horsepower           0
# Peak-rpm             0
# City-mpg             0
# Highway-mpg          0
# Price                0
# dtype: int64

# %% [markdown]
# Finally, the entire `automobile_new` dataframe's missing values are checked using `isnull()` function where all values are found `False` for all variables which means there are no missing vallues are demonstrating in this following datset. Apart from this, if this dataframe would get any `True` values, it would indicates about missing values here.

# %%
automobile_new.isnull()
# Out:
#      Symboling  Normalised-losses   Make  Fuel-type  Aspiration  Num-of-doors  \
# 3        False              False  False      False       False         False
# 4        False              False  False      False       False         False
# 6        False              False  False      False       False         False
# 8        False              False  False      False       False         False
# 10       False              False  False      False       False         False
# ..         ...                ...    ...        ...         ...           ...
# 228      False              False  False      False       False         False
# 229      False              False  False      False       False         False
# 230      False              False  False      False       False         False
# 232      False              False  False      False       False         False
# 233      False              False  False      False       False         False
#
# ...

# %% [markdown]
# ## Task 2: Data Exploration

# %% [markdown]
# # Task 2(Subtask 1): Chosen 3 columns

# %% [markdown]
# # Pie chart

# %% [markdown]
# Here, the libraries pandas, matplotlib and matplotlib.pyplot are imported as pd, mpl and plt respectively to explore the plots.

# %%
import pandas as pd
import matplotlib as mpl 
import matplotlib.pyplot as plt

from matplotlib.pyplot import plot

# %%
automobile_new['Engine-type'].value_counts()
# Here, the number of values of 'Engine-type' variable are checked again using `value_counts()` function and as an output 129,13,
# 12,10 numbers are found for 'ohc', 'dohc','ohcf', and 'ohcv' values respectively.
# Out:
# ohc     129
# dohc     13
# ohcf     12
# ohcv     10
# Name: Engine-type, dtype: int64

# %%
labels=automobile_new['Engine-type'].unique()
labels
# In this step, the 'Engine-type' variable has obtained 4 values uniquely using `unique()` function which named 
# as 'ohc','dohc','ohcv' and 'ohcf' and enlightened in the output.
# Out:
# array(['ohc', 'dohc', 'ohcv', 'ohcf'], dtype=object)

# %% [markdown]
# Here,the Pie chart graph has been chosen to explore the nominal variable’s statistical and graphical condition with proportionally which named as `Engine-type`.
#
# In the following step, the `Engine-types` variable's values proportions are comparing with the Pie chart which is subsetted with the `automobile_new` dataframe where the `value_counts()` is added with the `plot()` function to explore the pie chart explicitly. In this `plot()` function, there are some condition such as kind='pie' and autopct(acronym of auto percentage)='%.2f' which make this pie chart more readable and acceptable.The legend is used applying the `plt.legend()` function which provides the information of different values of the `Engine-type` variable's where `blue`, `orange`, `green` and `red` colors are highlighting `ohc`, `dohc`, `ohcf` and `ohcv` values respectively. According to the comparing of the values proportion, `ohc`, `ohcv`, `ohcf`, and `dohc` values are showing '78.66%', '6.10%', '7.32%', and '7.93%' respectively from following pie chart. Apart from this, the `plt.title()` function has been used to get the title name of the pie chart which named as `automobile_new-Engine-type Info` and highlighted in the output pane. As it is a circular statistical graph, it does not have any x-axis and y-axis.

# %%
automobile_new['Engine-type']\
      .value_counts()\
      .plot(kind='pie', autopct='%.2f')
plt.title('automobile_new - Engine-type Info')
plt.legend()
plot()
# Out:
# []

# %% [markdown]
# ## Histogram

# %%
labels=automobile_new['Num-of-cylinders'].unique() 
labels
# In this step, the 'Num-of cylinders' variable has obtained four values uniquely using the `unique()` function which 
# are highlighted as 4, 5, 6, and 3 in the output.
# Out:
# array([4, 5, 6, 3], dtype=int64)

# %% [markdown]
# Here, the libraries pandas, matplotlib and matplotlib.pyplot are imported as pd, mpl and plt respectively to explore the plots. In the following histogram graph, `Num-of-cylinders` variable is the subset of the `automobile_new` dataframe where `plot()` is highlighting the kind of `hist` which means histogram and bins= 4 means 4 different range of cylinders. After that, the `plt.title()` function has been used to get the title name of the pie chart which named as `automobile_new-cylinders Info` and highlighted in the output pane. Apart from this, the histogram has shown the xlabel or x-axis as `Num-of-cylinders` using the `plt.xlabel()` function whether it does not have any ylabel by default.Here, the `plt.legend()` function is applied to get the explicit information about the number of cylinders where `4` cylinders automobiles' frequency is higher than the other number of cylinders. Finally, the `plt.grid()` and `plt.show()` functions are applied to demonstrate the grid and to show the histogram graph explicitly.

# %%
import pandas as pd
import matplotlib as mpl 
import matplotlib.pyplot as plt

from matplotlib.pyplot import plot 
automobile_new['Num-of-cylinders'].plot(kind='hist',bins= 4)
plt.title('automobile_new - cylinders Info')
plt.xlabel('Num-of-cylinders')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Boxplot

# %% [markdown]
# According to the boxplot, it will give the information about the distribution of the data. Here, the boxplot is created in terms of the `Price` by `Num-of-doors` as well as the price is plotting onto the number of doors where two groups have been generated with the `four` and `two` number of doors using `by` effectively. Apart from this, `dropna()` function has been used in the below step to double-check and to drop the missing values during the operation time. After that, it is found that the `four` number of doors auto is more expensive than the `two` number of doors which are demonstrating from the following boxplot as well as the `two` number of doors are also highlighting few outliers. However, according to the median explanation, `four` doors auto is also more costly than the `two` doors auto. Here, the plt.title(), plt.xlabel() and plt.ylabel() functions are used to generate the title 'Price & Num-of-doors-Info', x-axis'Num-of-doors' and y-axis'Price' whether it does not have any legend by default which are shown in the following boxplot.

# %%
automobile_new.dropna().boxplot(column = 'Price', by = 'Num-of-doors', figsize=(8,5))
plt.title('Price & Num-of-doors-Info')
plt.xlabel('Num-of-doors')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ## Plotting with defined color palette:

# %%
colors_palette = {4:'red', 5:'green', 6:'blue', 3:'purple'}
# To find the color for each number of cylinders, different colors have been entitled with the different number of cylinders and
# made an object as `colors_palette`.

# %% [markdown]
# ## Finding the color for each Num-of-cylinders

# %%
colors = [colors_palette[integer_label] 
          for integer_label in automobile_new['Num-of-cylinders']]
# This `colors_palette` object has been subsetted with the `integer_label` and operated with the other subsetted function 
# named as `automobile_new['Num-of-cylinders']` to find the color for each number of cylinders where 'colors' is defined as object.

# %% [markdown]
# ## Plotting the graph

# %% [markdown]
# In the following scatter plot, the `plot()` has been used with the `automobile_new` dataframe where `plot()` function is highlighting the kind of `scatter` and added with x='City-mpg', y='Price', c='colors', figsize=(8,5). Here, x and y is plotting the x-axis and y-axis with `City-mpg` and `Price` as well as colors and figsize are highlighting the different colors of cylinders and the different size of the plotting figure respectively. After that, the `plt.title()` function has been used to get the title name of the scatter plot which named as automobile_new-City-mpg Info and highlighted in the output pane. Apart from this, the scatter plot has shown the xlabel or x-axis and ylable or y-axis as 'City-mpg' and 'Price'using the `plt.xlabel()` and `plt.ylabel()` function respectively. Here, the `plt.legend()` function is applied to get the explicit information about the number of cylinders where 4 cylinders automobiles' which are known as red dots in the following scatter plot which is comparatively more than the other number of cylinders or other dots colors. Finally, the `plt.grid()` and `plt.show()` functions are applied to demonstrate the grid and to show the scatter plot explicitly.

# %%
automobile_new.plot(kind='scatter',
                   x='City-mpg', y='Price',
                   c=colors, figsize=(8,5))
plt.title('automobile_new - City-mpg Info')
plt.legend('colors_palette')
plt.xlabel('City-mpg')
plt.ylabel('Price')
plt.grid()
plt.show()

# %% [markdown]
# # Task 2(Subtask 2): The relationships between columns

# %% [markdown]
# According to the boxplot, it will give the information about the distribution of the data. Here, the boxplot is generated in terms of the Price by Fuel-type as well as the price is plotting onto the `Fuel-type` where two groups have been formed with the `diesel` and `gas` using `groupby` effectively. Apart from this, `dropna()` function has been used in the below step to double-check and to drop the missing values during the operation time. After that, it is found that the `Fuel-type` of the automobiles are demonstrating different price where `diesel` is showing higher price than the `gas` which are demonstrating in the following boxplot as well as `gas` is also highlighting one outliers here. However, according to the median explanation, `diesel` holder autos are more expensive than the `gas` holder auto which is highlighting from the below boxplot. Here, the plt.title(), plt.xlabel() and plt.ylabel() functions are applied to create the title 'Price & Fuel-type-relation-Info', x-axis'Fuel-type' and y-axis'Price' whether it does not have any legend by default which are shown in the following boxplot.

# %%
automobile_new.dropna().boxplot(column = 'Price', by = 'Fuel-type', figsize=(8,5))
plt.title('Price & Fuel-type-relation-Info')
plt.xlabel('Fuel-type')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# In the following scatter plot, the plot() has been used with the automobile_new dataframe where plot() function is highlighting the kind of scatter and added with x='Horsepower', y='Price', c='colors', figsize=(8,5). Here, x and y is plotting the x-axis and y-axis with `Horsepower` and `Price` as well as `colors` and `figsize` are highlighting the different colors of cylinders and the different size of the plotting figure respectively. After that, the `plt.title()` function has been used to get the title name of the scatter plot which named as automobile_new-Horsepower Info and highlighted in the output pane. Apart from this, the scatter plot has shown the `xlabel` or x-axis and `ylable` or y-axis as 'Horsepower' and 'Price'using the `plt.xlabel()` and `plt.ylabel()` function respectively. Here, the `plt.legend()` function is applied to get the explicit information about the number of cylinders where 4 cylinders automobiles' which are known as red dots in the following scatter plot which is having comparatively more horsepower than the other number of cylinders or other dots colors though blue dot or 6 cylinders autos are also literally showing their Horsepower more which are still less than 4 cylinders or red dots. Besides this, it is shown from the following scatter plot that 4 cylinders automobiles are cheaper than the other cylinders despite of having it's more `Horsepowers`. Therefore, as the more horsepower produces it's better acceleration which is a strong factor in its overall performance, 4 cylinders automobiles will be more usable and acceptable than the other cylinders automobiles to the respected users. Finally, the `plt.grid()` and `plt.show()` functions are applied to demonstrate the grid and to show the scatter plot explicitly.

# %%
automobile_new.plot(kind='scatter',
                   x='Horsepower', y='Price',
                   c=colors, figsize=(8,5))
plt.title('Price & Horsepower relation-Info')
plt.legend('colors_palette')
plt.xlabel('Horsepower')
plt.ylabel('Price')
plt.grid()
plt.show()

# %%
automobile_new['Drive-wheels'].value_counts()
# The 'value_counts()' function is used to find the 'Drive-wheels' variable's values number,  where 'fwd' and 'rwd' values are
# showing 106 and 58 numbers respectively.
# Out:
# fwd    106
# rwd     58
# Name: Drive-wheels, dtype: int64

# %% [markdown]
# In the following step, the boxplot is created in terms of the `Highway-mpg` by `Drive-wheels`as well as the `Highway-mpg` is plotting onto the `Drive-wheels` where two groups have been generated with the `fwd` and `rwd` using group by effectively. Apart from this, `dropna()` function is also used in the following operation to double-check and to drop the missing values.
# After that, it is found that the `Drive-wheels` of the automobiles are demonstrating with the different `Highway-mpg` where `fwd` is showing greater highway-mpg than the `rwd` which are demonstrating in the following boxplot as well as `fwd` is also highlighting three outliers in the upper fence and one outlier in the lower-fence. However, according to the median exploration, 'fwd(front wheel drive)'autos are more powerful to make highway-mpg(miles per gallon) drive than the 'rwd(rear wheel drive)' autos which is highlighting from the below boxplot. Here, the `plt.title()`, `plt.xlabel()` and `plt.ylabel()` functions have been used to create the title 'Drive-wheels & Highway-mpg-relation-Info', x-axis'Drive-wheels' and y-axis'Highway-mpg'  whether it does not have any legend by default which are shown in the following boxplot.

# %%
automobile_new.dropna().boxplot(column = 'Highway-mpg', by = 'Drive-wheels', figsize=(8,5))
plt.title('Drive-wheels & Highway-mpg-relation-Info')
plt.xlabel('Drive-wheels')
plt.ylabel('Highway-mpg')
plt.show()

# %% [markdown]
# ## Task 2(Subtask 3): Scatter matrix for all numerical variables

# %%
automobile_new.info()
# The `info()` function has been used again to find all numeric variables from the `automobile_new` datset.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 164 entries, 3 to 233
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Symboling          164 non-null    int64
#  1   Normalised-losses  164 non-null    float64
#  2   Make               164 non-null    object
#  3   Fuel-type          164 non-null    object
#  4   Aspiration         164 non-null    object
#  5   Num-of-doors       164 non-null    category
#  6   Body-style         164 non-null    object
#  7   Drive-wheels       164 non-null    object
#  8   Engine-location    164 non-null    object
#  9   Wheel-base         164 non-null    float64
#  10  Length             164 non-null    float64
#  11  Width              164 non-null    float64
#  12  Height             164 non-null    float64
#  13  Curb-weight        164 non-null    int64
#  14  Engine-type        164 non-null    object
#  15  Num-of-cylinders   164 non-null    int64
# ...

# %%
auto=automobile_new[['Symboling', 'Normalised-losses', 'Wheel-base', 'Length','Width','Height','Curb-weight', 'Engine-size', 
                     'Bore', 'Stroke', 'Compression-ratio', 'Peak-rpm', 'City-mpg', 'Highway-mpg', 'Price','Num-of-cylinders']]
auto
# In this step, The subset has been made with all numeric variables with the `automobile_new` dataset and gnerated an object 
# named as `auto`.
# Out:
#      Symboling  Normalised-losses  Wheel-base  Length  Width  Height  \
# 3            2              164.0        99.8   176.6   66.2    54.3
# 4            2              164.0        99.4   176.6   66.4    54.3
# 6            1              158.0       105.8   192.7   71.4    55.7
# 8            1              158.0       105.8   192.7   71.4    55.9
# 10           2              192.0       101.2   176.8   64.8    54.3
# ..         ...                ...         ...     ...    ...     ...
# 228         -1               95.0       109.1   188.8   68.9    55.5
# 229         -1               95.0       109.1   188.8   68.9    55.5
# 230         -1               95.0       109.1   188.8   68.9    55.5
# 232         -1               95.0       109.1   188.8   68.8    55.5
# 233         -1               95.0       109.1   188.8   68.9    55.5
#
#      Curb-weight  Engine-size  Bore  Stroke  Compression-ratio  Peak-rpm  \
# ...

# %% [markdown]
# Here, the libraries pandas, matplotlib.pyplot are imported as pd and plt respectively to explore the scatter matrix plots.
#
# The `scatter_matrix` has been imported from `pandas.plotting` library and used  `auto` dataframe which has been made with the 16 numerical variables to make the scatter matrix plot where these features will make correlation with each other. During this operation, the `scatter_matrix()` funtion is applied where tranparency condition `alpha` is 1.0 to make the strong visualisation and figsize is 20 by 20 means it is shown the square figure and highlighted the histogram within the line chart using the `diagonal=hist`condition.
#
# From this below scatter matrix diagram, it is represents from the histogram chart that how the `Symboling` varibale is distributed with it's all values where it's shown almost normalised position. But, comparing with the `Symboling` feature's distribution the `Num-of-cylinders` feature's distribution is less-normalised. Here, all variables are highlighting their histogram chart like the `Symboling` variable in diagonally where these features are making strong correlation with each other. As this scatter matrix plot is plotted with more than one variable, that is why it is known as scatter matrix plot where all different features are plotted against all other features(variables). Additionally, it is also demonstrated the weakest correlation with the featues which is shown in the top right corner of the scatter matrix plot.

# %%
import pandas as pd
from matplotlib.pyplot import plot 
from pandas.plotting import scatter_matrix

scatter_matrix(auto,alpha= 1.0, figsize= (20,20), diagonal = 'hist')
plot()
# Out:
# []
